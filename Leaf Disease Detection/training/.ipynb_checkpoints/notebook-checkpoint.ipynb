# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNEL = 3
EPOCHS = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "DATASET",
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)   
# 68 * 32
# Out:
# 68

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_names[label_batch[i]])
        plt.axis(False)

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 54

# %%
rest_ds = dataset.skip(54)
val_size = 0.1
test_size = 0.1

# %%
test_size*len(dataset)
# Out:
# 6.800000000000001

# %%
val_ds = rest_ds.take(6)
test_ds = rest_ds.skip(6)
print(len(val_ds),len(test_ds))
# Out:
# 6 8

# %%
def get_dataset_partitions_tf(ds,train_split=0.8,val_split=0.1,test_split=0.1,shuffle=True,shuffle_size=1000):
    ds_size = len(ds)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed = 12)

    train_size = int(ds_size*train_split)
    val_size = int(ds_size*val_split)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds,val_ds,test_ds

# %%
train_ds,val_ds,test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
train_ds =  train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds =  val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds =  test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255),
])

# %% [markdown]
# ### Reprocess the modal before training by flip and rotation

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip('horizontal_and_vertical'),
    layers.experimental.preprocessing.RandomRotation(0.2),
    ])

# %% [markdown]
# ### CNN

# %%
INPUT_SHAPE = (BATCH_SIZE,IMAGE_SIZE,IMAGE_SIZE,CHANNEL)
N_CLASSES = 3

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32,(3,3),activation='relu',input_shape = INPUT_SHAPE),
    layers.MaxPool2D((2,2)),

    layers.Conv2D(64,kernel_size = (3,3),activation='relu'),
    layers.MaxPool2D((2,2)),

    layers.Conv2D(64,kernel_size = (3,3),activation='relu'),
    layers.MaxPool2D((2,2)),

    layers.Conv2D(64,kernel_size = (3,3),activation='relu'),
    layers.MaxPool2D((2,2)),

    layers.Conv2D(64,kernel_size = (3,3),activation='relu'),
    layers.MaxPool2D((2,2)),

    layers.Conv2D(64,kernel_size = (3,3),activation='relu'),
    layers.MaxPool2D((2,2)),

    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(N_CLASSES,activation='softmax')
])

model.build(input_shape = INPUT_SHAPE)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# There is a bug in keras/tensorflow 2.9 and 2.10, which causes preprocess layers like rescaling to be extremly slow: https://github.com/tensorflow/tensorflow/issues/56242

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_2 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 254, 254, 32)      896
#
#  max_pooling2d_6 (MaxPooling  (None, 127, 127, 32)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_7 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 60, 60, 64)        36928
#
#  max_pooling2d_8 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 12, 12, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 6, 6, 64)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 64)          36928
#
#  max_pooling2d_11 (MaxPoolin  (None, 2, 2, 64)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 183,747
# Trainable params: 183,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics = ['accuracy']
)

# %%
history = model.fit(train_ds,epochs=EPOCHS,batch_size=BATCH_SIZE,verbose=1,validation_data=val_ds)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 54/54 [==============================] - 176s 3s/step - loss: 0.9042 - accuracy: 0.4936 - val_loss: 0.9170 - val_accuracy: 0.5000
# Epoch 2/50
# 54/54 [==============================] - 107s 2s/step - loss: 0.7118 - accuracy: 0.6615 - val_loss: 0.5359 - val_accuracy: 0.7656
# Epoch 3/50
# 54/54 [==============================] - 103s 2s/step - loss: 0.4243 - accuracy: 0.8287 - val_loss: 0.3963 - val_accuracy: 0.8177
# Epoch 4/50
# 54/54 [==============================] - 99s 2s/step - loss: 0.3197 - accuracy: 0.8646 - val_loss: 0.2931 - val_accuracy: 0.8854
# Epoch 5/50
# 54/54 [==============================] - 101s 2s/step - loss: 0.3499 - accuracy: 0.8536 - val_loss: 0.2742 - val_accuracy: 0.8958
# Epoch 6/50
# 54/54 [==============================] - 105s 2s/step - loss: 0.2119 - accuracy: 0.9057 - val_loss: 0.3753 - val_accuracy: 0.8594
# Epoch 7/50
# 54/54 [==============================] - 113s 2s/step - loss: 0.1942 - accuracy: 0.9178 - val_loss: 0.5122 - val_accuracy: 0.8021
# Epoch 8/50
# 54/54 [==============================] - 117s 2s/step - loss: 0.1856 - accuracy: 0.9277 - val_loss: 0.2755 - val_accuracy: 0.8906
# Epoch 9/50
# 54/54 [==============================] - 113s 2s/step - loss: 0.1550 - accuracy: 0.9375 - val_loss: 0.2346 - val_accuracy: 0.8958
# Epoch 10/50
# 54/54 [==============================] - 105s 2s/step - loss: 0.1132 - accuracy: 0.9606 - val_loss: 0.4225 - val_accuracy: 0.8906
# Epoch 11/50
# 54/54 [==============================] - 104s 2s/step - loss: 0.1152 - accuracy: 0.9601 - val_loss: 0.1298 - val_accuracy: 0.9479
# Epoch 12/50
# 54/54 [==============================] - 102s 2s/step - loss: 0.0949 - accuracy: 0.9635 - val_loss: 0.2698 - val_accuracy: 0.9115
# Epoch 13/50
# 54/54 [==============================] - 96s 2s/step - loss: 0.0782 - accuracy: 0.9716 - val_loss: 0.7006 - val_accuracy: 0.8125
# Epoch 14/50
# 54/54 [==============================] - 94s 2s/step - loss: 0.1042 - accuracy: 0.9647 - val_loss: 0.1000 - val_accuracy: 0.9635
# Epoch 15/50
# 54/54 [==============================] - 94s 2s/step - loss: 0.1046 - accuracy: 0.9635 - val_loss: 0.2252 - val_accuracy: 0.8906
# Epoch 16/50
# 54/54 [==============================] - 96s 2s/step - loss: 0.0917 - accuracy: 0.9676 - val_loss: 0.1427 - val_accuracy: 0.9479
# Epoch 17/50
# 54/54 [==============================] - 99s 2s/step - loss: 0.0609 - accuracy: 0.9769 - val_loss: 0.3386 - val_accuracy: 0.9010
# Epoch 18/50
# 54/54 [==============================] - 98s 2s/step - loss: 0.0789 - accuracy: 0.9751 - val_loss: 0.0616 - val_accuracy: 0.9792
# Epoch 19/50
# 54/54 [==============================] - 103s 2s/step - loss: 0.0544 - accuracy: 0.9803 - val_loss: 0.0561 - val_accuracy: 0.9792
# Epoch 20/50
# 54/54 [==============================] - 98s 2s/step - loss: 0.0503 - accuracy: 0.9844 - val_loss: 0.0950 - val_accuracy: 0.9531
# Epoch 21/50
# 54/54 [==============================] - 97s 2s/step - loss: 0.0686 - accuracy: 0.9769 - val_loss: 0.0620 - val_accuracy: 0.9740
# Epoch 22/50
# 54/54 [==============================] - 97s 2s/step - loss: 0.0621 - accuracy: 0.9769 - val_loss: 0.0891 - val_accuracy: 0.9688
# Epoch 23/50
# 54/54 [==============================] - 98s 2s/step - loss: 0.0436 - accuracy: 0.9855 - val_loss: 0.0349 - val_accuracy: 0.9896
# Epoch 24/50
# 54/54 [==============================] - 92s 2s/step - loss: 0.0402 - accuracy: 0.9873 - val_loss: 0.1290 - val_accuracy: 0.9583
# Epoch 25/50
# 54/54 [==============================] - 95s 2s/step - loss: 0.0276 - accuracy: 0.9884 - val_loss: 0.2399 - val_accuracy: 0.9167
# Epoch 26/50
# 54/54 [==============================] - 95s 2s/step - loss: 0.0296 - accuracy: 0.9919 - val_loss: 0.1509 - val_accuracy: 0.9219
# Epoch 27/50
# 54/54 [==============================] - 101s 2s/step - loss: 0.0593 - accuracy: 0.9797 - val_loss: 0.0216 - val_accuracy: 0.9948
# Epoch 28/50
# 54/54 [==============================] - 100s 2s/step - loss: 0.0399 - accuracy: 0.9832 - val_loss: 0.0490 - val_accuracy: 0.9792
# Epoch 29/50
# 54/54 [==============================] - 104s 2s/step - loss: 0.0356 - accuracy: 0.9884 - val_loss: 0.0951 - val_accuracy: 0.9635
# Epoch 30/50
# 54/54 [==============================] - 102s 2s/step - loss: 0.0179 - accuracy: 0.9919 - val_loss: 0.5055 - val_accuracy: 0.8698
# Epoch 31/50
# 54/54 [==============================] - 106s 2s/step - loss: 0.0528 - accuracy: 0.9809 - val_loss: 0.0373 - val_accuracy: 0.9792
# Epoch 32/50
# 54/54 [==============================] - 102s 2s/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 0.0715 - val_accuracy: 0.9792
# Epoch 33/50
# 54/54 [==============================] - 105s 2s/step - loss: 0.0175 - accuracy: 0.9936 - val_loss: 0.2679 - val_accuracy: 0.9167
# Epoch 34/50
# 54/54 [==============================] - 102s 2s/step - loss: 0.0153 - accuracy: 0.9942 - val_loss: 0.0173 - val_accuracy: 0.9948
# Epoch 35/50
# 54/54 [==============================] - 96s 2s/step - loss: 0.0079 - accuracy: 0.9994 - val_loss: 0.0136 - val_accuracy: 0.9948
# Epoch 36/50
# 54/54 [==============================] - 98s 2s/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.1472 - val_accuracy: 0.9427
# Epoch 37/50
# 54/54 [==============================] - 99s 2s/step - loss: 0.0473 - accuracy: 0.9850 - val_loss: 0.0527 - val_accuracy: 0.9740
# Epoch 38/50
# 54/54 [==============================] - 101s 2s/step - loss: 0.0247 - accuracy: 0.9913 - val_loss: 0.0955 - val_accuracy: 0.9688
# Epoch 39/50
# 54/54 [==============================] - 98s 2s/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 0.0323 - val_accuracy: 0.9896
# Epoch 40/50
# 54/54 [==============================] - 94s 2s/step - loss: 0.0350 - accuracy: 0.9878 - val_loss: 0.0655 - val_accuracy: 0.9740
# Epoch 41/50
# 54/54 [==============================] - 101s 2s/step - loss: 0.0313 - accuracy: 0.9913 - val_loss: 1.1610 - val_accuracy: 0.8229
# Epoch 42/50
# 54/54 [==============================] - 98s 2s/step - loss: 0.0548 - accuracy: 0.9774 - val_loss: 0.0885 - val_accuracy: 0.9688
# Epoch 43/50
# 54/54 [==============================] - 100s 2s/step - loss: 0.0358 - accuracy: 0.9838 - val_loss: 0.0083 - val_accuracy: 0.9948
# Epoch 44/50
# 54/54 [==============================] - 98s 2s/step - loss: 0.0179 - accuracy: 0.9919 - val_loss: 0.0648 - val_accuracy: 0.9792
# Epoch 45/50
# 54/54 [==============================] - 95s 2s/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.0600 - val_accuracy: 0.9688
# Epoch 46/50
# 54/54 [==============================] - 97s 2s/step - loss: 0.0132 - accuracy: 0.9936 - val_loss: 0.0734 - val_accuracy: 0.9740
# Epoch 47/50
# 54/54 [==============================] - 96s 2s/step - loss: 0.0068 - accuracy: 0.9965 - val_loss: 0.1259 - val_accuracy: 0.9583
# Epoch 48/50
# 54/54 [==============================] - 105s 2s/step - loss: 0.0159 - accuracy: 0.9954 - val_loss: 0.1237 - val_accuracy: 0.9323
# Epoch 49/50
# 54/54 [==============================] - 100s 2s/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 0.0207 - val_accuracy: 0.9896
# Epoch 50/50
# 54/54 [==============================] - 97s 2s/step - loss: 0.0204 - accuracy: 0.9936 - val_loss: 0.0038 - val_accuracy: 1.0000

# %%
scores  = model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 3s 329ms/step - loss: 0.0077 - accuracy: 1.0000

# %%
scores
# Out:
# [0.007684200070798397, 1.0]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 54}

# %%
history.history.keys()
len(history.history.keys())
# Out:
# 4

# %%
history.history['accuracy']
# Out:
# [0.49363425374031067,
#  0.6614583134651184,
#  0.8287037014961243,
#  0.8645833134651184,
#  0.8535879850387573,
#  0.9056712985038757,
#  0.9178240895271301,
#  0.9276620149612427,
#  0.9375,
#  0.9606481194496155,
#  0.9600694179534912,
#  0.9635416865348816,
#  0.9716435074806213,
#  0.9646990895271301,
#  0.9635416865348816,
#  0.9675925970077515,
#  0.9768518805503845,
#  0.9751157164573669,
#  0.9803240895271301,
#  0.984375,
#  0.9768518805503845,
#  0.9768518805503845,
#  0.9855324029922485,
#  0.9872685074806213,
#  0.9884259104728699,
#  0.9918981194496155,
#  0.9797453880310059,
#  0.9832175970077515,
#  0.9884259104728699,
#  0.9918981194496155,
#  0.9809027910232544,
#  0.9947916865348816,
#  0.9936342835426331,
#  0.9942129850387573,
#  0.9994212985038757,
#  0.9982638955116272,
#  0.9849537014961243,
#  0.9913194179534912,
#  0.9947916865348816,
#  0.9878472089767456,
#  0.9913194179534912,
#  0.9774305820465088,
#  0.9837962985038757,
#  0.9918981194496155,
#  0.9988425970077515,
#  0.9936342835426331,
#  0.9965277910232544,
#  0.9953703880310059,
#  0.9924768805503845,
#  0.9936342835426331]

# %%
len(history.history['accuracy'])
# Out:
# 50

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title("Training & Validation Accuracy")

plt.subplot(1,2,2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='lower right')
plt.title("Training & Validation Loss")

plt.show()

# %%
import numpy as np
for images_batch,labels_batch in test_ds.take(1):
    first_image  = images_batch[0].numpy().astype('uint8')
    first_label = label_batch[0].numpy()

    print("First image to predict")
    plt.imshow(first_image)
    print("First Image's Label : ",class_names[first_label])

    batch_prediction = model.predict(image_batch)
    print("Predicted Label: ",class_names[np.argmax(batch_prediction[0])])
# Out:
# First image to predict
# First Image's Label :  Potato___Early_blight
# 1/1 [==============================] - 2s 2s/step
# Potato___Early_blight

# %%
def predict(model,img):
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array,0)

    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100*(np.max(predictions[0])),2)
    return predicted_class,confidence

# %%
plt.figure(figsize=(15,15))
for images,labels in test_ds.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype('uint8'))

        predicted_class,confidence = predict(model,images[i].numpy())
        actual_class = class_names[labels[i]]
        plt.title(f"Actual: {actual_class}\nPredicted Class {predicted_class}\nConfidence: {confidence}")
        plt.axis(False)
# Out:
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 80ms/step

# %%
import os

MODEL_VERSION  = max([int(i) for i in os.listdir('../models') + [0]]) + 1
model.save(f'../models/{MODEL_VERSION}')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/2\assets
# INFO:tensorflow:Assets written to: ../models/2\assets
